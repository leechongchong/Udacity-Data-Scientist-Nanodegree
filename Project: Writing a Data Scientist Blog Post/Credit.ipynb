# %% [markdown]
# # Data analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
import matplotlib.gridspec as gridspec
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('creditcard.csv')
df.info()
df.shape
df.describe().T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
# Time      284807 non-null float64
# V1        284807 non-null float64
# V2        284807 non-null float64
# V3        284807 non-null float64
# V4        284807 non-null float64
# V5        284807 non-null float64
# V6        284807 non-null float64
# V7        284807 non-null float64
# V8        284807 non-null float64
# V9        284807 non-null float64
# V10       284807 non-null float64
# V11       284807 non-null float64
# V12       284807 non-null float64
# V13       284807 non-null float64
# V14       284807 non-null float64
# V15       284807 non-null float64
# V16       284807 non-null float64
# V17       284807 non-null float64
# V18       284807 non-null float64
# V19       284807 non-null float64
# V20       284807 non-null float64
# V21       284807 non-null float64
# V22       284807 non-null float64
# V23       284807 non-null float64
# ...

# %%
df.groupby('Class').size()
# Out:
# Class
# 0    284315
# 1       492
# dtype: int64

# %%
import math
plt.figure(dpi=128,figsize=(8,4))
plt.minorticks_off()
plt.hist(df["Amount"][df["Class"]== 0], bins = 100, label = 'Normal', log=True,color = 'steelblue', alpha = 0.7)
plt.hist(df["Amount"][df["Class"]== 1], bins = 100, label = 'Fraud', log=True, color= 'orangered',alpha = 0.6)
plt.xlabel('Amount')
plt.ylabel('Number of Transactions')
plt.legend()
plt.show()

# %%
import seaborn as sns
time_val = df['Time'].values
fig, ax = plt.subplots(figsize=(18,4))
sns.distplot(time_val, color='b')
ax.set_title('Distribution of Transaction Time', fontsize=14)
ax.set_xlim([min(time_val), max(time_val)])
# Out:
# (0.0, 172792.0)

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(12,4))

bins = 50

ax1.hist(df.Time[df.Class == 1], bins = bins)
ax1.set_title('Fraud')

ax2.hist(df.Time[df.Class == 0], bins = bins)
ax2.set_title('Normal')

plt.xlabel('Time (in Seconds)')
plt.ylabel('Number of Transactions')
plt.show()

# %%
#Select only the anonymized features.
v_features = df.ix[:,1:29].columns
plt.figure(figsize=(12,28*4))
gs = gridspec.GridSpec(28, 1)
for i, cn in enumerate(df[v_features]):
    ax = plt.subplot(gs[i])
    sns.distplot(df[cn][df.Class == 1], bins=50)
    sns.distplot(df[cn][df.Class == 0], bins=50)
    ax.set_xlabel('')
    ax.set_title('histogram of feature: ' + str(cn))
plt.show()

# %% [markdown]
# # Smote data

# %%
import pandas as pd
import numpy as np
from sklearn.utils import shuffle
from imblearn.over_sampling import SMOTE

# %%
df = pd.read_csv('creditcard.csv')
columnname = df.columns.values.tolist()
columnname.pop()
fraud = shuffle(df[df.Class == 1])
normal = shuffle(df[df.Class == 0]) #打乱数据集

# %%
smo = SMOTE(random_state=42)
data_resampled_smo, data_labels_resampled_smo = smo.fit_sample(np.array(df.ix[:,df.columns != 'Class']), np.array(df.Class))

# %%
df_SMOTE = pd.DataFrame(data_resampled_smo, columns=columnname) 
df_label_SMOTE = pd.DataFrame(data_labels_resampled_smo,columns=['Class'])

# %%
df_new = pd.concat([df_SMOTE, df_label_SMOTE],axis=1)
df_new =shuffle(df_new)

# %%
df_new.to_csv("data_SMOTE.csv", index=False)

# %% [markdown]
# # Correlation coefficient

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("data_SMOTE.csv")
Data = df.copy(deep=True)

# %%
Target = Data['Class']
Data.drop('Class',axis=1,inplace=True) 
Data.drop('Amount',axis=1,inplace=True)
Data.drop('Time',axis=1,inplace=True)

# %%
correlationall = Data.corrwith(Target)
print(correlationall)
# Out:
# V1    -0.455660
# V2     0.529172
# V3    -0.594682
# V4     0.743132
# V5    -0.395104
# V6    -0.420335
# V7    -0.514479
# V8     0.053576
# V9    -0.599965
# V10   -0.660841
# V11    0.719427
# V12   -0.711355
# V13   -0.049583
# V14   -0.788245
# V15   -0.055115
# V16   -0.628636
# V17   -0.592992
# V18   -0.497451
# V19    0.296058
# V20    0.179650
# V21    0.139956
# V22   -0.008248
# V23   -0.002861
# V24   -0.102428
# V25    0.042713
# V26    0.062457
# V27    0.085723
# V28    0.099751
# dtype: float64

# %%
data_corr_result = pd.DataFrame(correlationall)
names = data_corr_result.index.values
corr = data_corr_result[0].values
corr = abs(corr)

# %%
name_larges, name_small, data_larges = [], [], []
for name, data in zip(names, corr):
    if data >=0.3:
        name_larges.append(name)
        data_larges.append(data)
    else:
        name_small.append(name)

# %%
print(name_larges, name_small)
# Out:
# ['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V9', 'V10', 'V11', 'V12', 'V14', 'V16', 'V17', 'V18'] ['V8', 'V13', 'V15', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28']

# %%
width = 0.5
figsize = (15,9)
figure, ax = plt.subplots(figsize=figsize)
idx = np.arange(len(data_larges))
plt.tick_params(labelsize=18)
plt.bar(idx, data_larges, facecolor='blue', width=0.8)
plt.xticks(idx+width/2, name_larges, rotation=40)
plt.show()

# %%
df.drop(name_small,axis=1,inplace=True)

# %%
df.to_csv('data_SMOTE_corr.csv', index=False)

# %% [markdown]
# # Logistic regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
import warnings
from pylab import mpl
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.model_selection import GridSearchCV
#%matplotlib inline
warnings.filterwarnings('ignore')

# %%
lr_data = pd.read_csv('data_SMOTE_corr.csv')

# %%
X = lr_data.drop('Class',axis=1)
y = lr_data['Class']

# %%
X=X.values
y=y.values

# %%
X_train_all, X_test, y_train_all, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
grid_param = {"C":[0.01, 0.1, 1, 10, 100]}

# %%
model = LogisticRegression()
grid = GridSearchCV(estimator=model,param_grid=grid_param, cv=5, scoring='f1')

# %%
grid.fit(X_train_all, y_train_all)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'C': [0.01, 0.1, 1, 10, 100]}, pre_dispatch='2*n_jobs',
#        refit=True, return_train_score=True, scoring='f1', verbose=0)

# %%
print(grid.best_params_)
# Out:
# {'C': 0.01}

# %%
lrn = LogisticRegression(C=0.01)
N = 5
skf = StratifiedKFold(n_splits = N, shuffle = True)
acc = []

# %%
for train_index, val_index in skf.split(X_train_all, y_train_all):
    X_train, y_train = X[train_index], y[train_index]
    X_val, y_val = X[val_index], y[val_index]
    lrn.fit(X_train, y_train)
    y_pred=lrn.predict(X_val)
    y_prob = lrn.predict_proba(X_val)[:,lrn.classes_[1]]
    acc.append(metrics.accuracy_score(y_pred,y_val))

# %%
np.mean(acc)
# Out:
# 0.96504631686079401

# %%
classes=['0' , '1' ]
y_pred = lrn.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
if lrn.classes_[0] == 1:
    cm = np.array([[cm[1,1], cm[1,0]], [cm[0,1], cm [0,0]]])
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)
thresh = cm.max() / 2.
import itertools
for i , j in itertools .product(range(cm.shape[0]), range(cm.shape[1])):
    plt .text(j , i , cm[i, j ],
    horizontalalignment="center",
    color="white" if cm[i, j ] > thresh else "black")
plt.tight_layout()
plt.ylabel('Actual Class') 
plt.xlabel('Predicted Class') 
# plt.savefig('fig-mx1.png', dpi=128)
plt.show()

# %%
print ('accuracy:%.3f' %metrics.accuracy_score(y_pred,y_test))
print ('precision:%.3f' %precision_score(y_true=y_test, y_pred=y_pred))
print ('recall:%.3f' %recall_score(y_true=y_test, y_pred=y_pred))
print ('F1:%.3f' %f1_score(y_true=y_test, y_pred=y_pred))
# Out:
# accuracy:0.963
# precision:0.985
# recall:0.941
# F1:0.962

# %% [markdown]
# # Adaboost

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
df = pd.read_csv("data_SMOTE_corr.csv", index_col=0)

# %%
X = df.drop(['Class'], axis=1)
y = df["Class"]
X=X.values
y=y.values
X_train_all, X_test, y_train_all, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
abc = AdaBoostClassifier(DecisionTreeClassifier(max_depth=1), algorithm="SAMME")

# %%
N = 5
skf = StratifiedKFold(n_splits = N, shuffle = True)
acc = []

# %%
for train_index, val_index in skf.split(X_train_all, y_train_all):
    X_train, y_train = X[train_index], y[train_index]
    X_val, y_val = X[val_index], y[val_index]
    abc.fit(X_train, y_train)
    y_pred = abc.predict(X_val)
    acc.append(metrics.accuracy_score(y_pred,y_val))

# %%
classes=['0' , '1' ]
y_pred = abc.predict(X_test)
cm = confusion_matrix(y_test, y_pred)

# %%
if abc.classes_[0] == 1:
    cm = np.array([[cm[1,1], cm[1,0]], [cm[0,1], cm [0,0]]])
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)
thresh = cm.max() / 2.
import itertools
for i , j in itertools .product(range(cm.shape[0]), range(cm.shape[1])):
    plt .text(j , i , cm[i, j ],
    horizontalalignment="center",
    color="white" if cm[i, j ] > thresh else "black")
plt.tight_layout()
plt.ylabel('Actual Class') 
plt.xlabel('Predicted Class') 
# plt.savefig('fig-mx1.png', dpi=128)
plt.show()

# %%
print ('accuracy:%.3f' %metrics.accuracy_score(y_pred,y_test))
print ('precision:%.3f' %precision_score(y_true=y_test, y_pred=y_pred))
print ('recall:%.3f' %recall_score(y_true=y_test, y_pred=y_pred))
print ('F1:%.3f' %f1_score(y_true=y_test, y_pred=y_pred))
# Out:
# accuracy:0.972
# precision:0.982
# recall:0.961
# F1:0.971

# %% [markdown]
# # Autoencoder

# %%
from keras.layers import Input, Dense
from keras.models import Model, Sequential
from keras import regularizers
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score
from sklearn.manifold import TSNE
from sklearn import preprocessing 
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
import seaborn as sns
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn import metrics
from sklearn.metrics import confusion_matrix

sns.set(style="whitegrid")
np.random.seed(203)
# Out:
# Using TensorFlow backend.

# %%
data = pd.read_csv("data_SMOTE.csv")
data["Time"] = data["Time"].apply(lambda x : x / 3600 % 24)
data.head()
# Out:
#         Time         V1         V2         V3        V4         V5        V6  \
# 0  17.323611  -1.103339  -0.059371   0.346566 -1.814450   0.791648 -0.776023
# 1  13.475975   1.006935   3.134176  -5.938569  5.793179   1.025669 -1.916878
# 2   1.339444   1.975720   0.667344  -3.158530  0.748844   1.959718 -0.054494
# 3   7.966781 -28.966471  16.059279 -29.825202  6.466650 -21.073684 -4.890061
# 4   6.741944  -0.576462   0.633457   1.793771 -0.928022  -0.095056 -0.760656
#
#           V7         V8        V9  ...         V21       V22       V23  \
# 0   0.692779  -0.672411 -0.978821  ...   -0.736469 -1.011699 -0.438651
# 1  -0.624172  -0.153489 -2.996974  ...    0.012532 -0.696175  0.091392
# 2   0.490866  -0.124227  1.276425  ...   -0.131895  0.195265  0.057749
# 3 -19.690875  19.023234 -3.626148  ...    1.808122 -2.156292 -1.348629
# 4   0.398110  -0.111579  1.258055  ...   -0.131339 -0.224796  0.069114
#
#         V24       V25       V26       V27       V28     Amount  Class
# ...

# %%
non_fraud = data[data['Class'] == 0].sample(1000)
fraud = data[data['Class'] == 1].sample(1000)

df = non_fraud.append(fraud).sample(frac=1).reset_index(drop=True)
X = df.drop(['Class'], axis = 1).values
Y = df["Class"].values

# %%
def tsne_plot(x1, y1, name="graph.png"):
    tsne = TSNE(n_components=2, random_state=0)
    X_t = tsne.fit_transform(x1)

    plt.figure(figsize=(12, 8))
    plt.scatter(X_t[np.where(y1 == 0), 0], X_t[np.where(y1 == 0), 1], marker='o', color='g', linewidth='1', alpha=0.8, label='Non Fraud')
    plt.scatter(X_t[np.where(y1 == 1), 0], X_t[np.where(y1 == 1), 1], marker='o', color='r', linewidth='1', alpha=0.8, label='Fraud')

    plt.legend(loc='best');
    plt.savefig(name);
    plt.show();
    
tsne_plot(X, Y, "original.png")

# %%
## input layer 
input_layer = Input(shape=(X.shape[1],))

## encoding part
encoded = Dense(100, activation='tanh', activity_regularizer=regularizers.l1(10e-5))(input_layer)
encoded = Dense(50, activation='relu')(encoded)

## decoding part
decoded = Dense(50, activation='tanh')(encoded)
decoded = Dense(100, activation='tanh')(decoded)

## output layer
output_layer = Dense(X.shape[1], activation='relu')(decoded)

autoencoder = Model(input_layer, output_layer)
autoencoder.compile(optimizer="adadelta", loss="mse")

# %%
x = data.drop(["Class"], axis=1)
y = data["Class"].values

x_scale = preprocessing.MinMaxScaler().fit_transform(x.values)
x_norm, x_fraud = x_scale[y == 0], x_scale[y == 1]

# %%
autoencoder.fit(x_norm, x_norm, 
                batch_size = 1024, epochs = 1, 
                shuffle = True, validation_split = 0.05);
# Out:
# Train on 270099 samples, validate on 14216 samples
# Epoch 1/1
# 270099/270099 [==============================] - 8s 29us/step - loss: 0.4560 - val_loss: 0.2926

# %%
hidden_representation = Sequential()
hidden_representation.add(autoencoder.layers[0])
hidden_representation.add(autoencoder.layers[1])
hidden_representation.add(autoencoder.layers[2])

# %%
# show the difference
norm_hid_rep = hidden_representation.predict(x_norm[0:1000])
fraud_hid_rep = hidden_representation.predict(x_fraud[0:1000])
rep_x = np.append(norm_hid_rep, fraud_hid_rep, axis = 0)
y_n = np.zeros(norm_hid_rep.shape[0])
y_f = np.ones(fraud_hid_rep.shape[0])
rep_y = np.append(y_n, y_f)
tsne_plot(rep_x, rep_y, "latentrep_y = np.append(y_n, y_f)_representation.png")

# %%
norm_hid_rep = hidden_representation.predict(x_norm)
fraud_hid_rep = hidden_representation.predict(x_fraud)

# %%
rep_x = np.append(norm_hid_rep, fraud_hid_rep, axis = 0)
y_n = np.zeros(norm_hid_rep.shape[0])
y_f = np.ones(fraud_hid_rep.shape[0])
rep_y = np.append(y_n, y_f)

# %%
train_x, val_x, train_y, val_y = train_test_split(rep_x, rep_y, test_size=0.3, random_state=42)
clf = LogisticRegression(solver="lbfgs").fit(train_x, train_y)
y_pred = clf.predict(val_x)

# %%
print ('accuracy:%.3f' %metrics.accuracy_score(y_pred,val_y))
print ('precision:%.3f' %precision_score(y_pred,val_y))
print ('recall:%.3f' %recall_score(y_pred,val_y))
print ('F1:%.3f' %f1_score(y_pred,val_y))
# Out:
# accuracy:0.973
# precision:0.958
# recall:0.988
# F1:0.973

# %%
classes=['0' , '1' ]
cm = confusion_matrix(val_y, y_pred)
if clf.classes_[0] == 1:
    cm = np.array([[cm[1,1], cm[1,0]], [cm[0,1], cm [0,0]]])
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)
thresh = cm.max() / 2.
import itertools
for i , j in itertools .product(range(cm.shape[0]), range(cm.shape[1])):
    plt .text(j , i , cm[i, j ],
    horizontalalignment="center",
    color="white" if cm[i, j ] > thresh else "black")
plt.tight_layout()
plt.ylabel('Actual Class') 
plt.xlabel('Predicted Class') 
# plt.savefig('fig-mx1.png', dpi=128)
plt.show()
